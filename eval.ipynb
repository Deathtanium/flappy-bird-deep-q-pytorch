# %%
import torch 
import numpy as np

import flappy_bird_gymnasium
import gymnasium

from deepq_agent import DQNAgent_pytorch

from gymnasium.wrappers import FlattenObservation

# %%
TARGET_UPDATE = 10
DEVICE = 'cuda' #torch.device("cuda" if torch.cuda.is_available() else "cpu")
LR = 1e-4
GAMMA = 0.99
EPS = 0
EPS_DECAY = 0.999
EPS_END = 0
BATCH_SIZE = 128
PLAY_MEMORY = 10000
LAYERS_SIZES = [32, 32]


EPOCHS = 1000000

# %%
env = gymnasium.make("FlappyBird-v0")
state,_ = env.reset()

# %%
#get size of observation space
obs_space = 11 #len(state) #overriden
act_space = env.action_space.n

obs_space, act_space
# Out:
# (11, 2)

# %%
agent = DQNAgent_pytorch(
        device=DEVICE,
        act_space=act_space,
        obs_space=obs_space,
        training_batch_size=BATCH_SIZE,
        learn_rate=LR,
        gamma=GAMMA,
        eps=EPS,                                                               #rate of exploration
        eps_decay_rate=EPS_DECAY,                                                   
        eps_floor=EPS_END,                                                       
        network_shape=LAYERS_SIZES,
        pmem_buffer_size=PLAY_MEMORY
    )

# %%
agent.load("model.pt")

# %%
env = gymnasium.make("FlappyBird-v0",render_mode='human')

env = FlattenObservation(env)

epochs_since_jump = 0
for i in range(EPOCHS):
    total_reward = 0
    state, _ = env.reset()
    state = torch.tensor(state[:-1], dtype=torch.float32, device=DEVICE).unsqueeze(0)
    terminated = False

    while not terminated:
        action = agent.get_action(state)
        real_action = action.item()
        if real_action == 1:
            if epochs_since_jump < 5:
                real_action = 0
                epochs_since_jump += 1
            else: 
                epochs_since_jump = 0
        else:
            epochs_since_jump += 1
        new_state, reward, terminated, truncated, info = env.step(real_action)
        if terminated or truncated: #or (new_state[9] < 0 or new_state[9] > 1):
            
            terminated = True
            
            #reset the environment
            state, _ = env.reset()
            state = torch.tensor(state[:-1], dtype=torch.float32, device=DEVICE).unsqueeze(0)
        else:
            #reward = 1
            pass
        
        total_reward += reward

        new_state = torch.tensor(new_state[:-1], dtype=torch.float32, device=DEVICE).unsqueeze(0)
        reward = torch.tensor([reward], device=DEVICE)
        #agent.remember(state, action, new_state, reward)
        #agent.train()

        state = new_state
    print("Iteration: ", i, "Total reward: ", total_reward)
# Out:
# Iteration:  0 Total reward:  8.99999999999998
# Iteration:  1 Total reward:  8.99999999999998
# Iteration:  2 Total reward:  8.99999999999998
# Iteration:  3 Total reward:  8.99999999999998
# Iteration:  4 Total reward:  8.99999999999998
# Iteration:  5 Total reward:  8.99999999999998
# Iteration:  6 Total reward:  2.1000000000000014
# Iteration:  7 Total reward:  2.1000000000000014
# Iteration:  8 Total reward:  2.1000000000000014
# Iteration:  9 Total reward:  2.1000000000000014
# Iteration:  10 Total reward:  2.1000000000000014
# Iteration:  11 Total reward:  2.3000000000000016
# Iteration:  12 Total reward:  2.3000000000000016
# Iteration:  13 Total reward:  2.3000000000000016
# Iteration:  14 Total reward:  2.3000000000000016
# Iteration:  15 Total reward:  8.99999999999998
# Iteration:  16 Total reward:  8.99999999999998
# Iteration:  17 Total reward:  8.99999999999998
# Iteration:  18 Total reward:  8.99999999999998
# Iteration:  19 Total reward:  8.99999999999998
# Iteration:  20 Total reward:  8.99999999999998
# Iteration:  21 Total reward:  8.99999999999998
# Iteration:  22 Total reward:  8.99999999999998
# Iteration:  23 Total reward:  8.99999999999998
# Iteration:  24 Total reward:  8.99999999999998
# Iteration:  25 Total reward:  8.99999999999998
# Iteration:  26 Total reward:  8.99999999999998
# Iteration:  27 Total reward:  3.3000000000000007
# Iteration:  28 Total reward:  8.99999999999998
# Iteration:  29 Total reward:  3.3000000000000007
# Iteration:  30 Total reward:  2.3000000000000016
# Iteration:  31 Total reward:  2.3000000000000016
# Iteration:  32 Total reward:  8.99999999999998
# Iteration:  33 Total reward:  8.99999999999998
# Iteration:  34 Total reward:  8.99999999999998
# Iteration:  35 Total reward:  5.799999999999992
# Iteration:  36 Total reward:  9.29999999999998
# Iteration:  37 Total reward:  8.99999999999998
# Iteration:  38 Total reward:  2.3000000000000016
# Iteration:  39 Total reward:  8.99999999999998
# Iteration:  40 Total reward:  4.299999999999997
# Iteration:  41 Total reward:  8.99999999999998
# Iteration:  42 Total reward:  9.29999999999998
# Iteration:  43 Total reward:  8.99999999999998
# Iteration:  44 Total reward:  8.99999999999998
# Iteration:  45 Total reward:  2.5000000000000018
# Iteration:  46 Total reward:  5.299999999999994
# Iteration:  47 Total reward:  8.99999999999998
# Iteration:  48 Total reward:  8.99999999999998
# Iteration:  49 Total reward:  9.899999999999977
# Iteration:  50 Total reward:  2.3000000000000016
# Iteration:  51 Total reward:  2.3000000000000016
# Iteration:  52 Total reward:  2.3000000000000016
# Iteration:  53 Total reward:  2.3000000000000016
# Iteration:  54 Total reward:  2.3000000000000016
# Iteration:  55 Total reward:  2.5000000000000018
# Iteration:  56 Total reward:  2.3000000000000016
# Iteration:  57 Total reward:  8.99999999999998
# Iteration:  58 Total reward:  2.3000000000000016
# Iteration:  59 Total reward:  2.3000000000000016
# Iteration:  60 Total reward:  4.299999999999997
# Iteration:  61 Total reward:  2.3000000000000016
# Iteration:  62 Total reward:  2.3000000000000016
# Iteration:  63 Total reward:  3.3000000000000007
# Iteration:  64 Total reward:  3.3000000000000007
# Iteration:  65 Total reward:  2.3000000000000016
# Iteration:  66 Total reward:  2.3000000000000016
# Iteration:  67 Total reward:  2.3000000000000016
# Iteration:  68 Total reward:  2.3000000000000016
# Iteration:  69 Total reward:  2.3000000000000016
# Iteration:  70 Total reward:  2.3000000000000016
# Iteration:  71 Total reward:  2.3000000000000016
# Iteration:  72 Total reward:  2.3000000000000016
# Iteration:  73 Total reward:  2.3000000000000016
# Iteration:  74 Total reward:  2.3000000000000016
# Iteration:  75 Total reward:  2.3000000000000016
# Iteration:  76 Total reward:  2.3000000000000016
# Iteration:  77 Total reward:  2.3000000000000016
# Iteration:  78 Total reward:  2.3000000000000016
# Iteration:  79 Total reward:  4.1999999999999975
# Iteration:  80 Total reward:  2.1000000000000014
# Iteration:  81 Total reward:  2.3000000000000016
# Iteration:  82 Total reward:  2.3000000000000016
# Iteration:  83 Total reward:  3.3000000000000007
# Iteration:  84 Total reward:  2.3000000000000016
# Iteration:  85 Total reward:  2.3000000000000016
# Iteration:  86 Total reward:  4.1999999999999975
# Iteration:  87 Total reward:  2.3000000000000016
# Iteration:  88 Total reward:  2.3000000000000016
# Iteration:  89 Total reward:  2.3000000000000016
# Iteration:  90 Total reward:  2.3000000000000016
# Iteration:  91 Total reward:  2.3000000000000016
# Iteration:  92 Total reward:  2.3000000000000016
# Iteration:  93 Total reward:  2.3000000000000016
# Iteration:  94 Total reward:  2.3000000000000016
# Iteration:  95 Total reward:  3.799999999999999
# Iteration:  96 Total reward:  4.1999999999999975
# Iteration:  97 Total reward:  5.299999999999994
# Iteration:  98 Total reward:  2.3000000000000016
# Iteration:  99 Total reward:  2.3000000000000016
# Iteration:  100 Total reward:  2.3000000000000016
# Iteration:  101 Total reward:  2.3000000000000016
# Iteration:  102 Total reward:  2.3000000000000016
# Iteration:  103 Total reward:  4.1999999999999975
# Iteration:  104 Total reward:  2.3000000000000016
# Iteration:  105 Total reward:  2.3000000000000016
# Iteration:  106 Total reward:  2.3000000000000016
# Iteration:  107 Total reward:  2.1000000000000014
# Iteration:  108 Total reward:  2.3000000000000016
# Iteration:  109 Total reward:  3.6999999999999993
# Iteration:  110 Total reward:  2.3000000000000016
# Iteration:  111 Total reward:  2.3000000000000016
# Iteration:  112 Total reward:  2.3000000000000016
# Iteration:  113 Total reward:  2.3000000000000016
# Iteration:  114 Total reward:  2.3000000000000016
# Iteration:  115 Total reward:  2.3000000000000016
# Iteration:  116 Total reward:  4.1999999999999975
# Iteration:  117 Total reward:  2.3000000000000016
# Iteration:  118 Total reward:  2.3000000000000016
# Iteration:  119 Total reward:  2.3000000000000016
# Iteration:  120 Total reward:  2.3000000000000016
# Iteration:  121 Total reward:  2.3000000000000016
# Iteration:  122 Total reward:  5.399999999999993
# Iteration:  123 Total reward:  2.3000000000000016
# Iteration:  124 Total reward:  3.6999999999999993
# Iteration:  125 Total reward:  2.3000000000000016
# Iteration:  126 Total reward:  2.3000000000000016
# Iteration:  127 Total reward:  2.3000000000000016
# Iteration:  128 Total reward:  3.799999999999999
# Iteration:  129 Total reward:  2.3000000000000016
# Iteration:  130 Total reward:  2.3000000000000016
# Iteration:  131 Total reward:  2.3000000000000016
# Iteration:  132 Total reward:  2.3000000000000016
# Iteration:  133 Total reward:  3.5
# Iteration:  134 Total reward:  2.3000000000000016
# Iteration:  135 Total reward:  2.3000000000000016
# Iteration:  136 Total reward:  2.3000000000000016
# Iteration:  137 Total reward:  2.3000000000000016
# Iteration:  138 Total reward:  2.3000000000000016
# Iteration:  139 Total reward:  2.3000000000000016
# Iteration:  140 Total reward:  2.3000000000000016
# Iteration:  141 Total reward:  2.3000000000000016
# Iteration:  142 Total reward:  2.3000000000000016
# Iteration:  143 Total reward:  2.3000000000000016
# Iteration:  144 Total reward:  2.3000000000000016
# Iteration:  145 Total reward:  6.099999999999991
# Iteration:  146 Total reward:  2.3000000000000016
# Iteration:  147 Total reward:  2.3000000000000016
# Iteration:  148 Total reward:  2.3000000000000016
# Iteration:  149 Total reward:  2.3000000000000016
# Iteration:  150 Total reward:  2.3000000000000016
# Iteration:  151 Total reward:  2.3000000000000016
# Iteration:  152 Total reward:  4.1999999999999975
# Iteration:  153 Total reward:  4.099999999999998
# Iteration:  154 Total reward:  2.3000000000000016
# Iteration:  155 Total reward:  2.3000000000000016
# Iteration:  156 Total reward:  2.3000000000000016
# Iteration:  157 Total reward:  2.3000000000000016
# Iteration:  158 Total reward:  3.799999999999999
# Iteration:  159 Total reward:  4.1999999999999975
# Iteration:  160 Total reward:  2.3000000000000016
# Iteration:  161 Total reward:  2.3000000000000016
# Iteration:  162 Total reward:  2.3000000000000016
# Iteration:  163 Total reward:  2.3000000000000016
# Iteration:  164 Total reward:  2.3000000000000016
# Iteration:  165 Total reward:  2.3000000000000016
# Iteration:  166 Total reward:  2.3000000000000016
# Iteration:  167 Total reward:  2.3000000000000016
# Iteration:  168 Total reward:  4.099999999999998
# Iteration:  169 Total reward:  2.3000000000000016
# Iteration:  170 Total reward:  4.1999999999999975
# Iteration:  171 Total reward:  2.3000000000000016
# Iteration:  172 Total reward:  3.5
# Iteration:  173 Total reward:  4.1999999999999975
# Iteration:  174 Total reward:  2.3000000000000016
# Iteration:  175 Total reward:  2.3000000000000016
# Iteration:  176 Total reward:  4.1999999999999975
# Iteration:  177 Total reward:  2.3000000000000016
# Iteration:  178 Total reward:  2.3000000000000016
# Iteration:  179 Total reward:  2.3000000000000016
# Iteration:  180 Total reward:  2.3000000000000016
# Iteration:  181 Total reward:  2.3000000000000016
# Iteration:  182 Total reward:  2.3000000000000016
# Iteration:  183 Total reward:  2.3000000000000016
# Iteration:  184 Total reward:  2.3000000000000016
# Iteration:  185 Total reward:  2.3000000000000016
# Iteration:  186 Total reward:  2.3000000000000016
# Iteration:  187 Total reward:  2.3000000000000016
# Iteration:  188 Total reward:  2.3000000000000016
# Iteration:  189 Total reward:  2.3000000000000016
# Iteration:  190 Total reward:  2.3000000000000016
# Iteration:  191 Total reward:  2.3000000000000016
# Iteration:  192 Total reward:  2.3000000000000016
# Iteration:  193 Total reward:  2.3000000000000016
# Iteration:  194 Total reward:  2.3000000000000016
# Iteration:  195 Total reward:  2.3000000000000016
# Iteration:  196 Total reward:  2.3000000000000016
# Iteration:  197 Total reward:  2.3000000000000016
# Iteration:  198 Total reward:  2.3000000000000016
# Iteration:  199 Total reward:  2.3000000000000016
# Iteration:  200 Total reward:  2.3000000000000016
# Iteration:  201 Total reward:  2.3000000000000016
# Iteration:  202 Total reward:  2.3000000000000016
# Iteration:  203 Total reward:  2.3000000000000016
# Iteration:  204 Total reward:  2.3000000000000016
# Iteration:  205 Total reward:  2.3000000000000016
# Iteration:  206 Total reward:  2.3000000000000016
# Iteration:  207 Total reward:  2.3000000000000016
# Iteration:  208 Total reward:  2.3000000000000016
# Iteration:  209 Total reward:  2.3000000000000016
# Iteration:  210 Total reward:  2.3000000000000016
# Iteration:  211 Total reward:  2.3000000000000016
# Iteration:  212 Total reward:  2.3000000000000016
# Iteration:  213 Total reward:  2.3000000000000016
# Iteration:  214 Total reward:  4.1999999999999975
# Iteration:  215 Total reward:  2.3000000000000016
# Iteration:  216 Total reward:  2.3000000000000016
# Iteration:  217 Total reward:  2.3000000000000016
# Iteration:  218 Total reward:  2.3000000000000016
# Iteration:  219 Total reward:  2.3000000000000016
# Iteration:  220 Total reward:  2.3000000000000016
# Iteration:  221 Total reward:  2.3000000000000016
# Iteration:  222 Total reward:  2.3000000000000016
# Iteration:  223 Total reward:  2.3000000000000016
# Iteration:  224 Total reward:  2.3000000000000016
# Iteration:  225 Total reward:  2.3000000000000016
# Iteration:  226 Total reward:  2.3000000000000016
# Iteration:  227 Total reward:  2.3000000000000016
# Iteration:  228 Total reward:  2.3000000000000016
# Iteration:  229 Total reward:  2.3000000000000016
# Iteration:  230 Total reward:  2.1000000000000014
# Iteration:  231 Total reward:  2.3000000000000016
# Iteration:  232 Total reward:  2.3000000000000016
# Iteration:  233 Total reward:  2.3000000000000016
# Iteration:  234 Total reward:  2.3000000000000016
# Iteration:  235 Total reward:  2.3000000000000016
# Iteration:  236 Total reward:  2.3000000000000016
# Iteration:  237 Total reward:  5.699999999999992
# Iteration:  238 Total reward:  2.3000000000000016
# Iteration:  239 Total reward:  2.3000000000000016
# Iteration:  240 Total reward:  2.3000000000000016
# Iteration:  241 Total reward:  2.3000000000000016
# Iteration:  242 Total reward:  7.099999999999987
# Iteration:  243 Total reward:  2.3000000000000016
# Iteration:  244 Total reward:  2.3000000000000016
# Iteration:  245 Total reward:  2.3000000000000016
# Iteration:  246 Total reward:  4.1999999999999975
# Iteration:  247 Total reward:  2.3000000000000016
# Iteration:  248 Total reward:  2.3000000000000016
# Iteration:  249 Total reward:  2.3000000000000016
# Iteration:  250 Total reward:  2.3000000000000016
# Iteration:  251 Total reward:  2.3000000000000016
# Iteration:  252 Total reward:  2.3000000000000016
# Iteration:  253 Total reward:  2.3000000000000016
# Iteration:  254 Total reward:  3.4000000000000004
# Iteration:  255 Total reward:  2.3000000000000016
# Iteration:  256 Total reward:  2.3000000000000016
# Iteration:  257 Total reward:  2.3000000000000016
# Iteration:  258 Total reward:  2.3000000000000016
# Iteration:  259 Total reward:  2.3000000000000016
# Iteration:  260 Total reward:  2.1000000000000014
# Iteration:  261 Total reward:  2.3000000000000016
# Iteration:  262 Total reward:  2.3000000000000016
# Iteration:  263 Total reward:  2.3000000000000016
# Iteration:  264 Total reward:  2.3000000000000016
# Iteration:  265 Total reward:  2.3000000000000016
# Iteration:  266 Total reward:  2.3000000000000016
# Iteration:  267 Total reward:  2.3000000000000016
# Iteration:  268 Total reward:  2.3000000000000016
# Iteration:  269 Total reward:  2.3000000000000016
# Iteration:  270 Total reward:  2.3000000000000016
# Iteration:  271 Total reward:  2.3000000000000016
# Iteration:  272 Total reward:  2.3000000000000016
# Iteration:  273 Total reward:  4.1999999999999975
